# %% [markdown]
# # CNN Image Sign Detection and Classification Assignment
# # ITM 360 002 By Sreytoch Brak (Spring 2026)
#
# This notebook:
# 1. Loads the **Finger Signs Detection Dataset** from Kaggle
# 2. Trains the sample CNN Model
# 3. Trains a **New CNN model**
# 4. **Compares performance** of both models

# %% [markdown]
# ---
# ## 1. Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import numpy as np
import time

# %%
# Configuration
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 32
IMG_SIZE = 224
EPOCHS = 10
LR = 0.001

# %%
# Data Transforms (Existing Model)
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# #Load Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("maneesh99/signs-detection-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'signs-detection-dataset' dataset.
# Path to dataset files: /kaggle/input/signs-detection-dataset

# %%
import os

# List the contents of the downloaded dataset path to understand its structure
print(os.listdir(path))
# Out:
# ['Signs_Data_Training.h5', 'Signs_Data_Testing.h5']
